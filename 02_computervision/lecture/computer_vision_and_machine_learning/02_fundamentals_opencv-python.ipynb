# %% [markdown]
# ## <font color = "#CC3D3D">Case #1: Image attributes</font>

# %% [markdown]
# <hr>
#
# ### Step #1: Attribute compositions
# <hr>
#
# - OpenCV는 영상 데이터를 numpy.ndarray로 표현한다.
# - 영상 데이터를 표현하는 속성들
#     - ndim : n dimention. n is unknown. 차원 수를 의미.
#         - e.g., 그레이스케일 영상은 h, w 2차원이고, 컬러 영상은 h, w, 3(RGB) 으로 3차원의 형태이다.
#     - shape : 각 차원의 크기를 의미.
#         - e.g., (h, w) or (h, w, 3) for return value.
#     - size : 전체 원소의 개수를 의미.
#         - e.g., h x w or h x w x 3 for return value.
#     - dtype : 원소의 자료형을 의미.<br>
# 일반적인 영상 데이터는 1px 당 1byte로 색상 정보를<br>
# 표현하기 때문에 uint8 자료형을 가진다.
#     - `참고사항:`
#         - dtype : 데이터 타입(자료형태)
#         - type : 오브젝트 타입(객체형태)
#         - numpy.ndarray : NumPy 라이브러리의 차원이 n개인 행렬

# %% [markdown]
# <hr>
#
# ### Step #2: OpenCV and NumPy data types
# <hr>
#
# |OpenCV 자료형(1채널)|NumPy 자료형|구분|
# |:-|:-|:-|
# |cv2.CV_8U|numpy.uint8|8비트 부호 없는 정수|
# |cv2.CV_8S|numpy.int8|8비트 부호 있는 정수|
# |cv2.CV_16U|numpy.uint16|16비트 부호 없는 정수|
# |cv2.CV_16S|numpy.int16|16비트 부호 있는 정수|
# |cv2.CV_32S|numpy.int32|32비트 부호 있는 정수|
# |cv2.CV_16F|numpy.float16|16비트 부동소수형|
# |cv2.CV_32F|numpy.float32|32비트 부동소수형|
# |cv2.CV_64F|numpy.float64|64비트 부동소수형|
#
# - 그레이스케일 영상 : cv2.CV_8UC1(8비트 부호 없는 정수이고, 채널이 1개이다.) -> numpy.uint8, shape = (h, w)
# - 컬러 영상 : cv2.CV_8UC3(8비트 부호 없는 정수이고, 채널이 3개이다.) -> numpy.uint8, shape = (h, w, 3)

# %% [markdown]
# <hr>
#
# ### Step #3: Search attributes
# <hr>

# %%
# 영상의 속성 탐색하기
import cv2


image1 = cv2.imread('./images/cat.bmp', cv2.IMREAD_GRAYSCALE)  # load image as grayscale.
image2 = cv2.imread('./images/cat.bmp')  # load image as color. default cv2.IMREAD_COLOR

# output images attrubutes.
print('image1 type :', type(image1))
print("image1 data type :", image1.dtype)
print('image2 type :', type(image2))
print("image2 data type :", image2.dtype)
print('-'*50)
print('image1 shape :', image1.shape)
print('image2 shape :', image2.shape)
print('-'*50)
print(f'image1 size : w x h x 1 = {image1.size}, 일반적으로 뒤에 " x 1" 부분은 생략해서 w x h 까지만 표현한다.')
print('image2 size : w x h x 3 =', image2.size)
print('-'*50)

# 115 ns ± 4.67 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
# if len(image1.shape) == 2:
#     print('image1 is a grayscale image')

# 52.6 ns ± 2.69 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
if image1.ndim == 2:
    print('image1 is a grayscale image')

print('-'*50)

# 슬라이싱 기법을 사용하여 원하는 픽셀 값 가져오기
x = 20
y = 10
pixel1 = image1[y, x]
pixel2 = image2[y, x]
print(pixel1)
print('[B G R] =', pixel2)
# Out:
# image1 type : <class 'numpy.ndarray'>
# image1 data type : uint8
# image2 type : <class 'numpy.ndarray'>
# image2 data type : uint8
# --------------------------------------------------
# image1 shape : (480, 640)
# image2 shape : (480, 640, 3)
# --------------------------------------------------
# image1 size : w x h x 1 = 307200, 일반적으로 뒤에 " x 1" 부분은 생략해서 w x h 까지만 표현한다.
# image2 size : w x h x 3 = 921600
# --------------------------------------------------
# image1 is a grayscale image
# --------------------------------------------------
# 238
# [B G R] = [237 242 232]

# %% [markdown]
# ## <font color="#CC3D3D">Case #2: Image handling</font>

# %% [markdown]
# <hr>
#
# ### Step #1: OpenCV function
# <hr>
#
# > `지정한 크기로 새 영상을 생성하는 NumPy 함수들`
# $$\mathsf{{\color{RoyalBlue}numpy.}{\color{Tan}empty}(shape, dtype, ...)\rightarrow ndarray}$$
# $$\mathsf{{\color{RoyalBlue}numpy.}{\color{Tan}zeros}(shape, dtype, ...)\rightarrow ndarray}$$
# $$\mathsf{{\color{RoyalBlue}numpy.}{\color{Tan}ones}(shape, dtype, ...)\rightarrow ndarray}$$
# $$\mathsf{{\color{RoyalBlue}numpy.}{\color{Tan}full}(shape, fill\_ value, dtype, ...)\rightarrow ndarray}$$
# - shape : 각 차원의 크기 - (h, w) or (h, w, 3)
#     - i.e., 영상의 채널은 1채널 혹은 3채널 두가지 외에도 3채널 색상에 1개의 alpha 채널이 더 지원되는 png 파일도 있다. 총 4채널
# - dtype : data type. 원소의 데이터 타입. 일반적인 영상이면 numpy.uint8 지정
# - ndarray : n dimention array. 생성된 영상(numpy.ndarray)
# - `참고사항:`
#     - numpy.empty() 함수는 임의의 값으로 초기화된 배열을 생성
#     - numpy.zeros() 함수는 0으로 초기화된 배열을 생성
#     - numpy.ones() 함수는 1로 초기화된 배열을 생성
#     - numpy.full() 함수는 정의된 fill\_value로 초기화된 배열을 생성

# %%
import numpy as np
help(np.empty)

# %%
import numpy as np
help(np.zeros)

# %%
import numpy as np
help(np.ones)

# %%
import numpy as np
help(np.full)

# %% [markdown]
# <hr>
#
# ### Step #2: Implementation example
# <hr>

# %%
# 4가지 함수를 각각 사용하여 새 배열을 생성하기
import cv2
import matplotlib.pyplot as plt
import numpy as np


# 각기 다른 새 영상 행렬 생성
image1 = np.empty((480, 640), np.uint8)
image2 = np.zeros((480, 640, 3), np.uint8)
image3 = np.ones((480, 640, 3), np.uint8) * 255
image4 = np.full((480, 640, 3), (0, 255, 255), np.uint8)

# 영상의 순서 변경 <- It's not necessary.
# image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)
# image3 = cv2.cvtColor(image3, cv2.COLOR_BGR2RGB)
# image4 = cv2.cvtColor(image4, cv2.COLOR_BGR2RGB)

# pyplot으로 출력
plt.figure(figsize=(10, 5), facecolor="lightgray")

plt.subplot(141).axis('off')
plt.imshow(image1, "gray")

plt.subplot(142).axis('off')
plt.imshow(image2)  # 색상 정보 순서를 변경하지 않아도 똑같이 검은색이 출력된다.

plt.subplot(143).axis('off')
plt.imshow(image3)  # 흰색도 검은색과 같이 순서 변경이 필요없다.

plt.subplot(144).axis('off')
# 단색조(grayscale: 0,0,0 ~ 255,255,255) 이외의 색상은 이처럼 순서 변경을 해주면 된다.
plt.imshow(image4[:, :, ::-1])

plt.show()

# %%
# 이미지 복사하기
import cv2
import matplotlib.pyplot as plt


image1 = cv2.imread('./images/HappyFish.jpg')

image2 = image1.copy()  # copy image1.

# 이 방법은 특정한 상황을 제외하고 권장되지 않음
image3 = image1  # image1을 참조하여 image3를 선언한다.
image3.fill(0)  # image3은 image1을 참조하였기 때문에 이 실행문은 image1과 image3에 동시에 영향을 끼친다.

# pyplot으로 출력
plt.figure(figsize=(10, 5), facecolor="lightgray")

plt.subplot(131).axis('off')
plt.imshow(image1)

plt.subplot(132).axis('off')
plt.imshow(image2[:, :, ::-1])

plt.subplot(133).axis('off')
plt.imshow(image3)

plt.show()

# %%
# 부분 영상 추출하기
import cv2
import matplotlib.pyplot as plt


image1 = cv2.imread('./images/HappyFish.jpg')

# (30, 40)을 왼쪽 위 꼭지점의 위치로 하는 120 x 80 크기의 직사각형 영역을 슬라이싱 기법으로 추출
image2 = image1[40:120, 30:150]

# image3는 image1이 온전할 때 복사되었기 때문에 후에 image1에 어떠한 영향이 있을지라도
# image3에는 해당 영향이 미치지 않고 온전하게 남아있는다.
image3 = image1[40:120, 30:150].copy()

image2.fill(0)  # image1과 image2에 동시에 영향을 끼친다.

# pyplot으로 출력
plt.figure(figsize=(10, 5), facecolor="lightgray")

plt.subplot(131).axis('off')
plt.imshow(image1[:, :, ::-1])

plt.subplot(132).axis('off')
plt.imshow(image2)

plt.subplot(133).axis('off')
plt.imshow(image3[:, :, ::-1])

plt.show()

# %% [markdown]
# ## <font color="#CC3D3D">Case #3: Mask operation</font>

# %% [markdown]
# <hr>
#
# ### ROI
# <hr>
#
# - Region of Interest(관심 영역)
# - 영상에서 특정 연산을 수행하고자 하는 임의의 부분 영역

# %% [markdown]
# <hr>
#
# ### Step #1: How to mask operation
# <hr>
#
# - 마스크 연산
#     - OpenCV는 일부 함수에 대해 ROI연산을 지원하며, 이 때 마스크 영상을 인수로 함께 전달해야 한다.
#         - e.g., cv2.copyTo(), cv2.calcHist(), cv2.bitwise_or(), cv2.matchTemplate()
#     - 마스크 영상은 cv2.CV_8UC1 타입(그레이스케일 영상)이다.
#     - 마스크 영상의 픽셀 값이 0이 아닌 위치에서만 연산이 수행된다.
#         - i.e., 보통 마스크 영상으로는 0 또는 255로 구성된 이진 영상(binary image)을 사용한다.
#     - src(입력영상), mask(마스크영상), dst(결과영상)는 크기가 `모두` 같아야 한다.
#         - i.e., 정리하자면 `src와 dst는 같은 타입`이어야 하고, `mask는 그레이스케일 타입의 이진 영상`이다.<br>
#     그리고 `src, mask, dst는 모두 크기가 같아야 한다.`

# %% [markdown]
# <hr>
#
# ### Step #2: OpenCV function
# <hr>
#
# > `마스크 연산을 지원하는 픽셀 값 복사 함수`
# $$\mathsf{{\color{RoyalBlue}cv2.}{\color{Tan}copyTo}(src, mask, dst)\rightarrow dst}$$
# - src : source matrix. 입력 영상. 영상 파일의 경로와 파일 이름 등의 정보를 함축한다.
# - mask : 마스크 영상. cv2.CV_8U(numpy.uint8)<br>
# `0이 아닌 픽셀`에 대해서만 복사 연산을 수행
# - dst : destination matrix. 출력 영상. 만약 src와 크기 및 타입이 같은 dst를 입력으로 지정하면<br>
# dst를 새로 생성하지 않고 연산을 수행한다.<br>
# 그렇지 않으면 `src와 같은 크기, 같은 타입의 dst를 새로 생성`하여 연산을 수행한 후 반환한다.

# %%
import cv2
help(cv2.copyTo)

# %% [markdown]
# <hr>
#
# ### Step #3: Implementation example
# <hr>

# %%
# 마스크 연산 수행하기 1
import cv2
import matplotlib.pyplot as plt


source = cv2.imread('./images/airplane.bmp')
mask = cv2.imread('./images/mask_plane.bmp', cv2.IMREAD_GRAYSCALE)
destination = cv2.imread('./images/field.bmp')

# pyplot으로 출력
plt.figure(figsize=(12, 6), facecolor="lightgray")

plt.subplot(131).axis('off')
plt.imshow(source[:, :, ::-1])

plt.subplot(132).axis('off')
plt.imshow(mask, cmap='gray')

plt.subplot(133).axis('off')
plt.imshow(destination[:, :, ::-1])

plt.show()

cv2.copyTo(source, mask, destination)  # Get masked image

# 또 다른 방법으로는 NumPy에서 제공하는 불리언 인덱싱 방법으로도 동일한 마스크 연산을 실행할 수 있다.
# destination[mask > 0] = source[mask > 0]

plt.figure(facecolor="lightgray")
plt.imshow(destination[:, :, ::-1])
plt.axis('off')
plt.show()

# %%
# 마스크 연산 수행하기 2
import cv2
import matplotlib.pyplot as plt


source = cv2.imread('./images/opencv-logo-white.png', cv2.IMREAD_UNCHANGED)
destination = cv2.imread('./images/cat.bmp')

mask = source[:, :, 3]  # alpha channel
source = source[:, :, :-1]  # BGR channels

# source와 destination의 크기가 다르다.
print("shape of source :", source.shape)
print("shape of destination :", destination.shape)

# destination에서 source와 같은 크기의 영역을 참조한 crop이라는 변수는 마스크연산을 수행하고,
# 동시에 원본에 영향을 끼친다. 이러한 상황이 바로 '참조가 필요한 경우'의 좋은 예시이다.
h, w = mask.shape
crop = destination[10:10 + h, 10:10 + w]

# pyplot으로 출력
plt.figure(figsize=(8, 4), facecolor="lightgray")

plt.subplot(131).axis('off')
plt.imshow(source[:, :, ::-1])

plt.subplot(132).axis('off')
plt.imshow(mask, cmap='gray')

plt.subplot(133).axis('off')
plt.imshow(crop[:, :, ::-1])

plt.show()

cv2.copyTo(source, mask, crop)

cv2.imwrite("images/masked_cat.bmp", destination)

plt.figure(facecolor="lightgray")
plt.imshow(destination[:, :, ::-1])
plt.axis('off')
plt.show()
# Out:
# shape of source : (222, 180, 3)
# shape of destination : (480, 640, 3)

# %% [markdown]
# ## <font color="#CC3D3D">Case #4: Drawing</font>

# %% [markdown]
# <hr>
#
# ### Step #1: Reference
# <hr>
#
# - OpenCV는 영상에 선, 도형, 문자열을 출력하는 그리기 함수를 제공한다.
#     - 선 그리기 : 직선, 화살표, 마커 등
#     - 도형 그리기 : 사각형, 원, 타원, 다각형 등
#     - 문자열 출력
# <hr>
#
# - OpenCV 그리기 함수 사용 시 주의할 점
#     - 그리기 알고리즘은 영상의 픽셀 값 자체를 변경한다.`(영상 훼손)`
#         - 원본 영상이 필요하면 `복사본`을 만들어서 그 위에 그리기 & 출력
#     - 그레이스케일 영상에는 컬러로 그리기가 안 된다.
#         - cv2.cvtColor() 함수로 `BGR 컬러 영상으로 변환`한 후 그리기 함수를 호출
#         - matplotlib 으로 출력할 시 RGB 컬러 영상으로 변환
# - 일반적으로 그리기 함수를 사용할 때 lineType은 `cv2.LINE_AA(안티 앨리어싱)`을<br>
# 주로 사용하여 가장자리가 거칠어지는 `계단 현상`을 방지한다.

# %% [markdown]
# <hr>
#
# ### Step #2: OpenCV function
# <hr>
#
# > `직선 그리기 함수`
# $$\mathsf{{\color{RoyalBlue}cv2.}{\color{Tan}line}(img, pt1, pt2, color, thickness, lineType, shift)\rightarrow img}$$
# - img : image. 그림을 그릴 영상
# - pt1 : point1. 직선의 시작점. (x, y) 튜플 형식
# - pt2 : point2. 직선의 끝점. (x, y) 튜플 형식
# - color : 선 색상 또는 밝기. (B, G, R) 튜플 또는 정수 값
# - thickness : 선 두께. `기본값은 1(px단위)`
# - lineType : 선 타입. cv2.LINE_4, cv2.LINE_8, cv2.LINE_AA 중 선택. `기본값은 cv2.LINE_8`
# - shift : 그리기 좌표 값의 축소 비율. `기본값은 0`
# <hr>
#
# > `사각형 그리기 함수`
# $$\mathsf{{\color{RoyalBlue}cv2.}{\color{Tan}rectangle}(img, pt1, pt2, color, thickness, lineType, shift)\rightarrow img}$$
# $$\mathsf{{\color{RoyalBlue}cv2.}{\color{Tan}rectangle}(img, rectangle, color, thickness, lineType, shift)\rightarrow img}$$
# - img : image. 그림을 그릴 영상
# - pt1 : point1. 사각형의 왼쪽 위 꼭지점 좌표. (x, y) 튜플 형식
# - pt2 : point2. 사각형의 오른쪽 아래 꼭지점 좌표. (x, y) 튜플 형식
# - rectangle : 사각형의 위치 정보. (x, y, w, h) 튜플 형식
#     - 여기서 x, y는 사각형의 왼쪽 위 꼭지점 좌표이다.
# - color : 선 색상 또는 밝기. (B, G, R) 튜플 또는 정수 값
# - thickness : 선 두께. `기본값은 1(px단위).` 음수(-1)를 지정하면 내부를 채운다.
# - lineType : 선 타입. cv2.LINE_4, cv2.LINE_8, cv2.LINE_AA 중 선택. `기본값은 cv2.LINE_8`
# - shift : 그리기 좌표 값의 축소 비율. `기본값은 0`
# <hr>
#
# > `원 그리기 함수`
# $$\mathsf{{\color{RoyalBlue}cv2.}{\color{Tan}circle}(img, center, radius, color, thickness, lineType, shift)\rightarrow img}$$
# - img : image. 그림을 그릴 영상
# - center : 원의 줌실점의 좌표. (x, y) 튜플 형식
# - radius : 원의 반지름. 정수값
# - color : 선 색상 또는 밝기. (B, G, R) 튜플 또는 정수 값
# - thickness : 선 두께. `기본값은 1(px단위).` 음수(-1)를 지정하면 내부를 채운다.
# - lineType : 선 타입. cv2.LINE_4, cv2.LINE_8, cv2.LINE_AA 중 선택. `기본값은 cv2.LINE_8`
# - shift : 그리기 좌표 값의 축소 비율. `기본값은 0`
# <hr>
#
# > `다각형 그리기 함수`
# $$\mathsf{{\color{RoyalBlue}cv2.}{\color{Tan}polylines}(img, [pts], isClosed, color, thickness, lineType, shift)\rightarrow img}$$
# - img : image. 그림을 그릴 영상
# - pts : points. 다각형 외곽 점들의 좌표 배열. numpy.ndarray를 리스트 형식으로 감싸서 전달한다.<br>
# 다각형 외곽 점들의 좌표 값은 시계 방향으로 지정한다.
#     - e.g., [np.array([[10, 10], [50, 50], [10, 50]], dtype=np.int32)]
# - isClosed : 폐곡선 여부. True or False로 지정.
#     - True이면 마지막 꼭지점과 첫 번째 꼭지점을 연결 시킨다.
#     - False이면 마지막 꼭지점과 첫 번째 꼭지점을 연결하지 않은 상태로 출력 한다.
# - color : 선 색상 또는 밝기. (B, G, R) 튜플 또는 정수 값
# - thickness : 선 두께. `기본값은 1(px단위).` 음수(-1)를 지정하면 내부를 채운다.
# - lineType : 선 타입. cv2.LINE_4, cv2.LINE_8, cv2.LINE_AA 중 선택. `기본값은 cv2.LINE_8`
# - shift : 그리기 좌표 값의 축소 비율. `기본값은 0`
# - `참고사항:`
#     - isClosed에 False를 전달하고 thickness에 -1(내부 채움)으로 지정하면 오류메세지를 반환한다.
#     - 다각형의 내부를 전달한 색상 값으로 채우고 싶으면 isClosed에 True를 전달해야 한다.
# <hr>
#
# > `문자열 출력 함수`
# $$\mathsf{{\color{RoyalBlue}cv2.}{\color{Tan}putText}(img, text, org, fontFace, fontScale, color, thickness,
#             lineType, bottomLeftOrigin)\rightarrow img}$$
# - img : image. 문자열을 그릴 영상
# - text : 출력할 문자열
# - org : origin. 영상에서 문자열을 출력할 위치의 좌측 하단 좌표. (x, y) 튜플 형식
# - fontFace : 폰트 종류. cv2.FONT_HERSHEY_ 로 시작하는 상수 중 선택
# - fontScale : 폰트 크기 확대/축소 비율(em단위)
# - color : 폰트 색상 또는 밝기. (B, G, R) 튜플 또는 정수 값
# - thickness : 폰트 두께. `기본값은 1(px단위)`
# - lineType : 선 타입. cv2.LINE_4, cv2.LINE_8, cv2.LINE_AA 중 선택. `기본값은 cv2.LINE_8`
# - bottomLeftOrigin : True이면 영상의 좌측 하단을 원점으로 간주한다. `기본값은 False`
# <hr>
#
# - cv2.putText()에서 지원하는 fontFace 상수와 실제 출력 모양
#
# <img src="images/markdown/fontface.png" width="600">

# %% [markdown]
# <hr>
#
# ### Step #3: Implementation example
# <hr>

# %%
# Try drawing in one place through 5 drawing function examples - 5개의 그리기 함수 예제를 통해 한 곳에 그려 넣어보기

# 참고사항 - OpenCV의 그리기 함수는 color 매개변수에 전달하는 색상 값을 BGR 순서로 받지만
# matplotlib 패키지는 RGB 순서로 인식하기 때문에 RGB 순서로 전달하여 원하는 색상을 표현할 예정이다.
import matplotlib.pyplot as plt
import numpy as np
import cv2

# 새 영상 생성하기(흰색 그림판)
print('새 그림판을 생성합니다.')
image = np.full(shape=(400, 400, 3), fill_value=255, dtype=np.uint8)

plt.figure(facecolor="lightgray")
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# 새 그림판을 생성합니다.

# %%
import cv2
help(cv2.line)

# %%
# 직선 그리기
print('직선 2개가 생성되었습니다.')
cv2.line(image, pt1=(50, 50), pt2=(200, 50), color=(255, 0, 0), thickness=5)
cv2.line(image, pt1=(50, 60), pt2=(150, 160), color=(128, 0, 0))

plt.figure(facecolor="lightgray")
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# 직선 2개가 생성되었습니다.

# %%
import cv2
help(cv2.rectangle)

# %%
# 사각형 그리기
print('사각형 2개가 생성되었습니다.')
cv2.rectangle(image, rec=(50, 200, 150, 100), color=(0, 255, 0), thickness=2)
cv2.rectangle(image, pt1=(70, 220), pt2=(180, 280), color=(0, 128, 0), thickness=-1)

plt.figure(facecolor="lightgray")
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# 사각형 2개가 생성되었습니다.

# %%
import cv2
help(cv2.circle)

# %%
# 원 그리기
print('원 2개가 생성되었습니다.')
cv2.circle(image, center=(300, 100), radius=60, color=(0, 0, 255),
           thickness=3, lineType=cv2.LINE_AA)
cv2.circle(image, center=(300, 100), radius=30, color=(0, 255, 255),
           thickness=-1, lineType=cv2.LINE_AA)

plt.figure(facecolor="lightgray")
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# 원 2개가 생성되었습니다.

# %%
import cv2
help(cv2.polylines)

# %%
# 다각형 그리기
print("사다리꼴 도형이 생성되었습니다.")
pts_ = np.array([[250, 200], [300, 200], [350, 300], [250, 300]])  # 시계 방향으로 지정
cv2.polylines(image, pts=[pts_], isClosed=True, color=(255, 0, 255),
              thickness=2, lineType=cv2.LINE_AA)

plt.figure(facecolor="lightgray")
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# 사다리꼴 도형이 생성되었습니다.

# %%
import cv2
help(cv2.putText)

# %%
# 문자열 출력
print('문구가 생성되었습니다.')
text_ = 'Hello? OpenCV ' + cv2.__version__
cv2.putText(image, text=text_, org=(50, 350), fontFace=cv2.FONT_HERSHEY_SIMPLEX,
            fontScale=.8, color=(255, 0, 0), lineType=cv2.LINE_AA)

plt.figure(facecolor="lightgray")
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# 문구가 생성되었습니다.

# %% [markdown]
# ## <font color="#CC3D3D">Case #5: Camera & Video processing</font>

# %% [markdown]
# <hr>
#
# ### Step #1: Explanation
# <hr>
#
# - OpenCV에서는 카메라와 동영상으로부터 프레임(frame)을 받아오는 작업을 cv2.VideoCapture 클래스 하나로 처리한다.

# %% [markdown]
# <hr>
#
# ### Step #2: OpenCV function
# <hr>
#
# > `카메라 열기 함수`
# $$\mathsf{{\color{RoyalBlue}cv2.}VideoCapture(index, apipreference)\rightarrow retval}$$
# - index : camera_id + domain_offset_id. 시스템 기본 카메라를 기본 방법으로 열려면 0을 전달
# - apipreference : 선호하는 카메라 처리 방법을 지정
# - retval : return value. cv2.VideoCapture 인스턴스(객체)
# $$\mathsf{{\color{RoyalBlue}cv2.}VideoCapture.{\color{Tan}open}(index, apiPreference)\rightarrow retval}$$
# - retval : return value. 성공하면 True, 실패하면 False
# <hr>
#
# > `동영상, 정지 영상 시퀀스, 비디오 스트림 열기 함수`
# $$\mathsf{{\color{RoyalBlue}cv2.}VideoCapture(filename, apipreference)\rightarrow retval}$$
# - filename : 비디오 파일이 있는 경로와 파일 이름. 그 외 정지 영상 시퀀스, 비디오 스트림 URL 등
# - apipreference : 선호하는 동영상 처리 방법을 지정
# - retval : return value. cv2.VideoCapture 인스턴스(객체)
# $$\mathsf{{\color{RoyalBlue}cv2.}VideoCapture.{\color{Tan}open}(filename, apipreference)\rightarrow retval}$$
# - retval : return value. 성공하면 True, 실패하면 False
# <hr>
#
# > `비디오 캡쳐가 준비되었는지 확인하는 함수`
# $$\mathsf{{\color{RoyalBlue}cv2.}VideoCapture.{\color{Tan}isOpened}()\rightarrow retval}$$
# - retval : return value. 성공하면 True, 실패하면 False
# <hr>
#
# > `프레임 받아 오기 함수`
# $$\mathsf{{\color{RoyalBlue}cv2.}VideoCapture.{\color{Tan}read}(image)\rightarrow retval, image}$$
# - retval : return value. 성공하면 True, 실패하면 False
# - image : 현재 프레임(numpy.ndarray)
# <hr>
#
# > `카메라, 비디오 장치 속성 값 참조 함수`
# $$\mathsf{{\color{RoyalBlue}cv2.}VideoCapture.{\color{Tan}get}(propId)\rightarrow retval}$$
# - propId : property identity. 속성 상수
# - retval : return value. 성공하면 해당 속성 값, 실패하면 0
# $$\mathsf{{\color{RoyalBlue}cv2.}VideoCapture.{\color{Tan}set}(propId, value)\rightarrow retval}$$
# - propId : property identity. 속성 상수
# - value : 속성 값
# - retval : return value. 성공하면 True, 실패하면 False
# <hr>
#
# > `할당된 자원을 해제하는 함수`
# $$\mathsf{{\color{RoyalBlue}cv2.}VedeoCapture.{\color{Tan}release}()}$$

# %% [markdown]
# <hr>
#
# ### Step #3: Attribute constants
# <hr>
#
# [<OpenCV 문서 참고>](https://docs.opencv.org/4.1.0/d4/d15/group__videoio__flags__base.html#gaeb8dd9c89c10a5c63c139bf7c4f5704d "속성 상수")
#
# |속성 상수|설명|
# |:-|:-|
# |CAP_PROP_FRAME_WIDTH|프레임 가로 크기|
# |CAP_PROP_FRAME_HEIGHT|프레임 세로 크기|
# |CAP_PROP_FPS|초당 프레임 수|
# |CAP_PROP_FRAME_COUNT|비디로 파일의 총 프레임 수|
# |CAP_PROP_POS_MSEC|밀리초 단위로 현재 위치|
# |CAP_PROP_POS_FRAMES|현재 프레임 번호|
# |CAP_PROP_EXPOSURE|노출|
#
# ※ CAP_PROP -> capture device property
#
# ※ POS -> position

# %%
import cv2
help(cv2.VideoCapture)

# %% [markdown]
# <hr>
#
# ### Step #4: Implementation example
# <hr>

# %%
# Camera process example(Open the system basic camera device) - 카메라 처리 예제(시스템 기본 카메라 장치 열기)
import sys
import cv2

# 카메라 장치 열기
capture = cv2.VideoCapture(0)  # 인수를 0을 전달 함으로 시스템 기본 카메라 장치를 연다.

# 예외 처리
if not capture.isOpened():
    print('Camera open failed!')
    sys.exit()

# 카메라 프레임 크기 출력
print('Frame width :', int(capture.get(cv2.CAP_PROP_FRAME_WIDTH)))
print('Frame height :', int(capture.get(cv2.CAP_PROP_FRAME_HEIGHT)))

# 카메라 프레임 크기 설정
capture.set(cv2.CAP_PROP_FRAME_WIDTH, 320)
capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 240)

# 카메라 매 프레임 처리
while True:
    retval, frame = capture.read()  # 프레임 받아 오기 여부와 현재 프레임을 각각 retval, frame 변수에 할당
    
    # 반복문 탈출 조건문 1
    if not retval:  # 반환 값이 False일 때
        break
    
    inversed = ~frame  # 프레임 반전
    
    edge = cv2.Canny(frame, threshold1=50, threshold2=150)  # 윤곽선
    
    cv2.imshow('frame', frame)
    cv2.imshow('inversed', inversed)
    cv2.imshow('edge', edge)
    
    # 반복문 탈출 조건문 2
    if cv2.waitKey(1) == 27:  # esc키 누를 시 
        break

capture.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# Frame width : 1280
# Frame height : 720
# -1

# %%
# Video process example(Open a video in local file) - 동영상 처리 예제(로컬 파일에서 비디오 열기)
import sys
import cv2

# 비디오 파일 열기
capture = cv2.VideoCapture('./videos/video1.mp4')

# 예외 처리
if not capture.isOpened():
    print('Video open failed!')
    sys.exit()

# 비디오 프레임 크기, 전체 프레임수 출력
print('Frame width :', int(capture.get(cv2.CAP_PROP_FRAME_WIDTH)))
print('Frame height :', int(capture.get(cv2.CAP_PROP_FRAME_HEIGHT)))
print('Frame count :', int(capture.get(cv2.CAP_PROP_FRAME_COUNT)))

fps = round(capture.get(cv2.CAP_PROP_FPS))
# 초당 프레임 수 출력
print('FPS :', fps)
delay = round(1000 / fps)

# 비디오의 매 프레임 처리
while True:
    retval, frame = capture.read()
    
    # 반복문 탈출 조건문 1
    if not retval:  # 반환 값이 False일 때
        break
    
    inversed = ~frame  # 동영상 반전
    
    edge = cv2.Canny(frame, threshold1=50, threshold2=150)  # 윤곽선
    
    cv2.imshow('frame', frame)
    cv2.imshow('inversed', inversed)
    cv2.imshow('edge', edge)
    
    # 반복문 탈출 조건문 2
    if cv2.waitKey(delay) == 27:  # esc키 누를 시
        break

capture.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# Frame width : 1280
# Frame height : 720
# Frame count : 85
# FPS : 24
# -1

# %% [markdown]
# <hr>
#
# ### Step #5: Video processing
# <hr>
#
# - OpenCV에서는 cv2.VideoWriter 클래스를 이용하여 일련의 프레임을 동영상 파일로 저장할 수 있다.
# - 일련의 프레임은 모두 `크기`와 `데이터 타입`이 같아야 한다.
# <hr>
#
# - Fourcc(4-문자 코드, four character code)
#     - 동영상 파일의 코덱, 압축 방식, 색상, 픽셀 포맷 등을 정의하는 정수 값(아래 테이블 참고)
#
# |종류|설명|
# |:-|:-|
# |cv2.VideoWriter_fourcc(*'DIVX')|DIVX MPEG-4 코덱|
# |cv2.VideoWriter_fourcc(*'XVID')|XVID MPEG-4 코덱|
# |cv2.VideoWriter_fourcc(*'FMP4')|FFMPEG MPEG-4 코덱|
# |cv2.VideoWriter_fourcc(*'X264')|H.264/AVC 코덱|
# |cv2.VideoWriter_fourcc(*'MJPG')|Motion-JPEG 코덱|
#
# [https://www.fourcc.org/codecs.php](https://www.fourcc.org/codecs.php)

# %% [markdown]
# <hr>
#
# ### Step #6: OpenCV function
# <hr>
#
# > `저장을 위한 동영상 파일을 정의하는 함수`
# $$\mathsf{{\color{RoyalBlue}cv2.VideoWriter}(filename, fourcc, fps, frameSize, isColor)\rightarrow retval}$$
# - filename : 비디오 파일의 경로와 이름
# - fourcc : four character code. 4-문자 코드(위 테이블 참고)
# - fps : frame per second. 초당 프레임 수
# - frameSize : 프레임 크기(width, height) 튜플 형식
# - isColor : 컬러 영상이면 True, 그렇지 않으면 False
#     - 그레이스케일 영상을 저장할 때는 컬러 포맷(BGR)로 변환 후 저장해야 한다.
# - retval : return value. cv2.VideoWriter 인스턴스(객체)
# $$\mathsf{{\color{RoyalBlue}cv2.VideoWriter.}{\color{Tan}open}(filename, fourcc, fps, frameSize, isColor)\rightarrow retval}$$
# - retval : return value. 성공하면 True, 실패하면 False
# <hr>
#
# > `비디오 파일이 준비되었는지 확인하는 함수`
# $$\mathsf{{\color{RoyalBlue}cv2.VideoWriter.}{\color{Tan}isOpened}()\rightarrow retval}$$
# - retval : return value. 성공하면 True, 실패하면 False
# <hr>
#
# > `프레임을 저장하는 함수`
# $$\mathsf{{\color{RoyalBlue}cv2.VideoWriter.}{\color{Tan}write}(image)\rightarrow None}$$
# - image : 저장할 프레임(numpy.ndarray)

# %%
import cv2
help(cv2.VideoWriter)

# %% [markdown]
# <hr>
#
# ### Step #7: Implementation example
# <hr>

# %%
# Saving system default camera input as video - 시스템 기본 카메라 입력을 동영상으로 저장하기
import sys
import cv2

# 시스템 기본 카메라로 장치 열기
capture = cv2.VideoCapture(0)

# 예외 처리 1
if not capture.isOpened():
    print("Camera open failed!")
    sys.exit()

# 불러온 비디오 프레임 크기 구하기
width = round(capture.get(cv2.CAP_PROP_FRAME_WIDTH))
height = round(capture.get(cv2.CAP_PROP_FRAME_HEIGHT))

# 초 당 프레임 수 & 딜레이 구하기
# fps = round(capture.get(cv2.CAP_PROP_FPS))
# print(fps)
delay = round(1000 / 30)  # 딜레이 : 현재 프레임과 다음 프레임 사이의 시간 간격(밀리초 단위)
print(delay)

# 4-문자 코드 지정
fourcc = cv2.VideoWriter_fourcc(*'mp4v')

# 입력 받은 일련의 프레임들을 담을 동영상 파일 정의하기
# i.e., 맞춤형 상자를 제작해 거기에 프레임들을 담는다고 생각하자.
out = cv2.VideoWriter("./videos/edge_camera.mp4", fourcc, 30, (width, height))

# 예외 처리 2
if not out.isOpened():
    print("File open failed!")
    capture.release()
    sys.exit()

# 비디오의 매 프레임 처리
while True:
    retval, frame = capture.read()
    
    # 반복문 탈출 조건문 1
    if not retval:  # 반환 값이 False일 때
        break
    
    inversed = ~frame  # 비디오 반전
    
    edge = cv2.Canny(image=frame, threshold1=50, threshold2=150)  # 윤곽선
    # 윤곽선을 검출한 edge 영상은 그레이스케일 영상이기 때문에 컬러 영상으로 변환해야 저장 된다.
    edge_color = cv2.cvtColor(edge, cv2.COLOR_GRAY2BGR)
    
    out.write(edge_color)  # 받아온 프레임을 정의한 동영상 파일에 저장하기
    # out.write(frame)
    
    cv2.imshow('frame', frame)
    cv2.imshow('inversed', inversed)
    cv2.imshow('edge', edge)
    
    # 반복문 탈출 조건문 2
    if cv2.waitKey(delay) == 27:  # esc 누를 시
        break

capture.release()  # 할당된 자원을 해제
out.release()  # 동영상 상자를 닫음
cv2.destroyAllWindows()
cv2.waitKey(1)

# %% [markdown]
# ## <font color="#CC3D3D">Case #6: Keyboard event processing</font>

# %% [markdown]
# <hr>
#
# ### Step #1: OpenCV function
# <hr>
#
# > `키보드 입력 대기 함수`
# $$\mathsf{{\color{RoyalBlue}cv2.}{\color{Tan}waitkey}(delay)\rightarrow retval}$$
# - delay : 밀리초 단위 대기 시간. delay ≤ 0 이면 무한히 기다린다. `기본값은 0`
# - retval : return value. 눌린 키 값(ASCII code). 키가 눌리지 않으면 -1
# - `참고사항:`
#     - cv2.waitKey() 함수는 OpenCV 창이 하나라도 있을 때만 동작한다.
#     - 특정 키 입력을 사용하려면 ord() 함수를 이용

# %% [markdown]
# <hr>
#
# ### Step #2: waitKeyEx() function return value
# <hr>
#
# - Windows 운영체제에서 방향키, 함수키 등의 특수키 입력은 cv2.waitkeyEx() 함수를 사용한다.
#
# |특수 키|waitkeyEx() 반환값|특수 키|waitkeyEx() 반환값|
# |:-|:-|:-|:-|
# |Insert|0x2d0000|F1|0x700000|
# |Delete|0x2e0000|F2|0x710000|
# |Page Up|0x210000|F3|0x720000|
# |Page Down|0x220000|F4|0x730000|
# |End|0x230000|F5|0x740000|
# |Home|0x240000|F6|0x750000|
# |←|0x250000|F7|0x760000|
# |↑|0x260000|F8|0x770000|
# |→|0x270000|F9|0x780000|
# |↓|0x280000|F10|0x790000|
# |||F11|0x7a0000|
# |||F12|0x7b0000|

# %% [markdown]
# <hr>
#
# ### Step #3: Implementation example
# <hr>

# %%
# Invert the image by pressing the "i" or "I" key on the keyboard - 키보드에서 "i" 또는 "I" 키를 누르면 영상을 반전 시키기
import sys
import cv2

image = cv2.imread("./images/cat.bmp", cv2.IMREAD_GRAYSCALE)

cv2.imshow("image", image)

while True:
    # cv2.waitKey() 함수를 변수에 저장하지 않고 if와 elif에 두 번 사용하게 되면
    # 컴퓨터에서 cv2.waitKey() 함수를 각각의 조건문에서 한 번씩 입력을 받아
    # 총 두 번의 입력을 받아야지만 모든 조건문이 실행되기 때문에 아를 해결하기 위해
    # cv2.waitKey() 함수를 변수에 할당하여 사용하면 한 번의 입력으로 조건에 따라
    # 두 가지 실행을 할 수 있게 된다.
    keycode = cv2.waitKey()
    if keycode == ord('i') or keycode == ord('I'):
        image = ~image
        cv2.imshow("image", image)
    elif keycode == 27:
        break

cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %% [markdown]
# ## <font color="#CC3D3D">Case #7: Mouse event processing</font>

# %% [markdown]
# <hr>
#
# ### Step #1: Reference
# <hr>
#
# - OpenCV에서 cv2.namedWindow() 함수 혹은 cv2.imshow() 함수를 이용해 가상 윈도우 창을 만들 때,<br>
# 그 창에 대한 일반적인 이벤트 처리가 가능한데 이는 마우스가 움직일 때도 다양한 마우스 이벤트가 발생한다.<br>
# 다만 그 마우스 이벤트들이 거의 무시가 되는데, 원한다면 마우스 이벤트를 사용자에게 다시 되돌려 주도록<br>
# OpenCV 라이브러리에 요청을 할 수 있다. 그 요청을 하는 함수가 바로 cv2.setMouseCallback()함수 이다.<br>
# 이 함수는 내가 띄운 가상 윈도우 창에서 발생하는 어떤 마우스 이벤트를 사용자 임의대로 처리를 하고 싶을 때<br>
# 사용자가 등록한 사용자 정의 콜백 함수를 호출하여 그 함수의 실행문을 실행해주는 함수이다.<br>

# %% [markdown]
# <hr>
#
# ### Step #2: OpenCV function
# <hr>
#
# > `마우스 이벤트 콜백 함수 등록 함수`
# $$\mathsf{{\color{RoyalBlue}cv2.}{\color{Tan}setMouseCallback}(windowName, onMouse, param)\rightarrow None}$$
# - windowName : 마우스 이벤트 처리를 수행할 창 이름
# - onMouse : 마우스 이벤트 처리를 위한 콜백 함수 이름. 마우스 이벤트 콜백 함수는 특정한 형식을 따라야 한다.
# - param : 콜백 함수에 전달할 데이터<br>
# <hr>
#
# > `마우스 이벤트 처리 함수(콜백 함수) 형식`
# $$\mathsf{{\color{Tan}onMouse}(event, x, y, flags, param)\rightarrow None}$$
# - event : 마우스 이벤트 종류. cv2.EVENT_ 로 시작하는 상수
# - x : 마우스 이벤트가 발생한 x 좌표
# - y : 마우스 이벤트가 발생한 y 좌표
# - flags : 마우스 이벤트 발생 시 상태. cv2.EVENT_FLAG_ 로 시작하는 상수
# - param : cv2.setMouseCallback() 함수에서 설정한 데이터
# - `참고사항:`
#     - 콜백 함수와 파라미터의 이름 양식은 자유이다.(i.e., 다만 파라미터의 위치(순서)는 변경할 수 없다.)<br>
# -> CapitalizedWord or lower_case_with_underscores or mixedCase or something.
#     - 마우스 이벤트 종류는 아래 테이블 참조
#     - 마우스 이벤트가 발생할 때의 좌표(x, y)를 콜백함수의 x, y 파라미터가 인수로 넘겨받는다.
#     - 마우스 이벤트 발생 시 상태는 아래 테이블 참조

# %% [markdown]
# <hr>
#
# ### Step #3: Mouse event types
# <hr>
#
# |MouseEventTypes 열거형 상수|값|설명|
# |:-|--|:-|
# |cv2.EVENT_MOUSEMOVE|0|마우스가 창 위에서 움직이는 경우|
# |cv2.EVENT_LBUTTONDOWN|1|마우스 왼쪽 버튼이 눌려지는 경우|
# |cv2.EVENT_RBUTTOMDOWN|2|마우스 오른쪽 버튼이 눌려지는 경우|
# |cv2.EVENT_MBUTTONDOWN|3|마우스 가운데 버튼이 눌려지는 경우|
# |cv2.EVENT_LBUTTONUP|4|마우스 왼쪽 버튼이 떼어지는 경우|
# |cv2.EVENT_RBUTTONUP|5|마우스 오른쪽 버튼이 떼어지는 경우|
# |cv2.EVENT_MBUTTONUP|6|마우스 가운데 버튼이 떼어지는 경우|
# |cv2.EVENT_LBUTTONDBLCLK|7|마우스 왼쪽 버튼을 더블클릭하는 경우|
# |cv2.EVENT_RBUTTONDBLCLK|8|마우스 오른쪽 버튼을 더블클릭하는 경우|
# |cv2.EVENT_MBUTTONDBLCLK|9|마우스 가운데 버튼을 더블클릭하는 경우|
# |cv2.EVENT_MOUSEWHEEL|10|마우스 휠을 앞뒤로 돌리는 경우|
# |cv2.EVENT_MOUSEHWHEEL|11|마우스 휠을 좌우로 움직이는 경우|

# %% [markdown]
# <hr>
#
# ### Step #4: Mouse event flags
# <hr>
#
# |MouseEventFlags 열거형 상수|값|설명|
# |:-|--|:-|
# |cv2.EVENT_FLAG_LBUTTON|1|마우스 왼쪽 버튼이 눌려져 있음|
# |cv2.EVENT_FLAG_RBUTTON|2|마우스 오른쪽 버튼이 눌려져 있음|
# |cv2.EVENT_FLAG_MBUTTON|4|마우스 가운데 버튼이 눌려져 있음|
# |cv2.EVENT_FLAG_CTRLKEY|8|CTRL 키가 눌려져 있음|
# |cv2.EVENT_FLAG_SHIFTKEY|16|SHIFT 키가 눌려져 있음|
# |cv2.EVENT_FLAG_ALTKEY|32|ALT 키가 눌려져 있음|

# %%
import cv2
help(cv2.setMouseCallback)

# %% [markdown]
# <hr>
#
# ### Step #5: Implementation example
# <hr>

# %%
# Drawing a picture using mouse - 마우스를 이용해 그림 그리기
import sys
import cv2
import numpy as np

# 마우스 이벤트 발생 시 받아오는 좌표들을 이전과 현재로 구분하기 위해
# 이전 좌표를 의미하는 old_x, old_y라는 변수를 만든다.
old_x = old_y = -1


def on_mouse(event, x, y, flags, param):
    """Callback function of setMouseCallback()"""
    
    global image, old_x, old_y
    
    # if event == cv2.EVENT_LBUTTONDOWN:
    #     print(f"EVENT_LBUTTONDOWN : {x}, {y}")  # 마우스 왼쪽 버튼을 클릭할 시 좌표를 출력
    # elif event == cv2.EVENT_LBUTTONUP:
    #     print(f"EVENT_LBUTTONUP : {x}, {y}")  # 마우스 왼쪽 버튼을 뗄 시 좌표를 출력
    # elif event == cv2.EVENT_MOUSEMOVE:
    #     if flags & cv2.EVENT_FLAG_LBUTTON:
    #         print(f"EVENT_MOUSEMOVE : {x}, {y}")  # 마우스를 클릭한 상태로 움직일 시 좌표를 출력
    if event == cv2.EVENT_LBUTTONDOWN:
        old_x, old_y = x, y
    elif event == cv2.EVENT_MOUSEMOVE:
        if flags and cv2.EVENT_FLAG_LBUTTON:
            cv2.line(image, (old_x, old_y), (x, y), (0, 0, 255), 4, cv2.LINE_AA)
            cv2.imshow("image", image)
            old_x, old_y = x, y


image = np.ones((480, 640, 3), np.uint8) * 255

cv2.imshow("image", image)
# 마우스 이벤트 콜백 함수는 OpenCV 가상 윈도우 창이 열려 있는 상태에서 호출해야 되기 때문에
# cv2.namesWindow() 함수 혹은 cv2.imshow() 함수보다 밑에 작성해야 한다.
cv2.setMouseCallback("image", on_mouse)
cv2.waitKey()

cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %% [markdown]
# ## <font color="#CC3D3D">Case #8: Trackbar</font>

# %% [markdown]
# <hr>
#
# ### Step #1: What is trackbar?
# <hr>
#
# - 트랙바(Trackbar)
#     - 프로그램 동작 중 사용자가 지정한 범위 안의 값을 선택할 수 있는 컨트롤 바
#     - OpenCV에서 제공하는 (유일한?) GUI(Graphic User Interface)

# %% [markdown]
# <hr>
#
# ### Step #2: OpenCV function
# <hr>
#
# > `트랙바 생성 함수 - 마우스 이벤트 콜백 등록 함수 처럼 마지막에 사용자 정의 콜백 함수를 인수로 넘긴다.`
# $$\mathsf{{\color{RoyalBlue}cv2.}{\color{Tan}createTrackbar}(trackbarName, windowName, value, count, onChange)\rightarrow None}$$
# - trackbarName : 트랙바 이름
# - windowName : 트랙바를 생성할 창 이름
# - value : 트랙바 위치 초기값
# - count : 트랙바 최댓값. 최솟값은 항상 0
# - onChange : 트랙바 위치가 변경될 때마다 호출할 콜백 함수 이름<br>
# 트랙바 이벤트 콜백 함수는 다음의 형식을 따른다.
#     - e.g., onChange(position) -> None
# - `참고사항:`
#     - 트랙바 콜백 함수도 마우스 이벤트 처리 콜백 함수처럼 이름 양식과 파라미터 이름은 자유이다.<br>
# i.e., 다만 파라미터의 위치(순서)는 변경할 수 없다.

# %%
import cv2
help(cv2.createTrackbar)

# %% [markdown]
# <hr>
#
# ### Step #3: Implementation example
# <hr>

# %%
# Express grayscale level using trackbar - 트랙바를 이용한 그레이스케일 레벨 표현하기
import cv2
import numpy as np


def on_level_change(position):
    """
    Callback function by user definition."""
    
    color_value = position * 16  # 색상 크기(0 ~ 255, 256) -> 16 x 16 = 256
    
    # 16 x 16 = 256 이기 때문에 마지막 level에서 색상 크기가 0으로 바뀌어 적용 된다.
    # 그렇기에 if 조건문 또는 numpy.clip() 함수를 사용하여 마지막 level에 대해 처리한다.
    if color_value >= 255:
        color_value = 255
    
    # 이 방법은 트랙바 이벤트가 발생할 때마다(매 level 마다) 실행되기 때문에 비효율 적이라고 생각된다.
    # color_value = np.clip(color_value, 0, 255)
    
    image[:] = color_value
    cv2.imshow("image", image)


image = np.zeros((480, 640), np.uint8)

# 주의할 점 - 새 가상 윈도우 생성이 먼저 이루어지지 않으면 트랙바가 윈도우 사이즈보다 크게 생긴다.
cv2.namedWindow("image")

cv2.createTrackbar("level", "image", 0, 16, on_level_change)  # 트랙바 생성

cv2.imshow("image", image)

cv2.waitKey()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %%
# Express true color level using trackbar(+ switch) - 트랙바를 이용한 트루 컬러 레벨 표현하기(+ 스위치)
import cv2
import numpy as np


def on_change(position):
    """
    Callback function by user definition."""
    
    R = cv2.getTrackbarPos("R", "color palette")
    G = cv2.getTrackbarPos("G", "color palette")
    B = cv2.getTrackbarPos("B", "color palette")
    S = cv2.getTrackbarPos(switch, "color palette")
    
    if S == 0:
        color_palette[:] = 0
    else:
        color_palette[:] = [B,G,R]  # 모든 행/열 좌표값을 [B, G, R]로 변경
        
    cv2.imshow("color palette", color_palette)


color_palette = np.zeros((300, 512, 3), np.uint8)

cv2.namedWindow("color palette")

# trackbar를 생성하여 namedWindow에 등록
cv2.createTrackbar("R", "color palette", 0, 255, on_change)
cv2.createTrackbar("G", "color palette", 0, 255, on_change)
cv2.createTrackbar("B", "color palette", 0, 255, on_change)
switch = "0:OFF/1:On"
cv2.createTrackbar(switch, "color palette", 1, 1, on_change)

# OpenCV 가상 윈도우로 출력
cv2.imshow("color palette", color_palette)

cv2.waitKey()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %% [markdown]
# ## <font color="#CC3D3D">Case #9: Operating time measurement</font>

# %% [markdown]
# <hr>
#
# ### Step #1: Explanation
# <hr>
#
# - 컴퓨터 비전은 대용량 데이터를 다루고, 일련의 과정을 통해 최종 결과를 얻으므로<br>
# 매 단계에서 연산 시간을 측정하여 반드시 관리할 필요가 있다.<br>
# OpenCV에서는 TickMeter 클래스를 이용하여 연산 시간을 측정한다.

# %% [markdown]
# <hr>
#
# ### Step #2: OpenCV function
# <hr>
#
# > `연산 시간 측정 클래스`
# $$\mathsf{{\color{RoyalBlue}cv2.}{\color{Tan}TickMeter}()\rightarrow tm}$$
# - tm : cv2.TickMeter 클래스의 인스턴스(객체)
# - tm.start() : 시간 측정 시작
# - tm.stop() : 시간 측정 종료
# - tm.reset() : 시간 측정 초기화
#     - 예를 들어 두 개의 함수 실행 시간을 각각 측정하려고할 때 함수와 함수 사이에서 초기화를 한다.
# - tm.getTimeSec() : 측정 시간을 초 단위로 반환
# - tm.getTimeMilli() : 측정 시간을 밀리 초 단위로 반환
# - tm.getTimeMicro() : 측정 시간을 마이크로 초 단위로 반환

# %%
import cv2
help(cv2.TickMeter)

# %% [markdown]
# <hr>
#
# ### Step #3: Implementation example
# <hr>

# %%
# Example a time mesurement of operating - 연산의 시간 측정 예제
import cv2
import time

# 영상 불러오기
image = cv2.imread("./images/hongkong.jpg")

# 시간 측정 인스턴스 생성
tick_meter = cv2.TickMeter()
tick_meter.reset()

# 시간 측정 시작
tick_meter.start()  # OpenCV library
start_time = time.time()  # time library

# 연산 수행
height = image.shape[0]
width = image.shape[1]

for h in range(height):  # 영상의 전체 픽셀 5312 x 2988 만큼의 픽셀들을 하나씩 호출하여 전부 빨강색으로 바꿈
    for w in range(width):
        image[h, w] = (0, 0, 255)
        
        # 총 반복 횟수 구하기
        if h == height - 1:
            if w == width - 1:
                print("총 반복 횟수 : {:,}번".format((w+1) * (h+1)))

# 시간 측정 종료
tick_meter.stop()  # OpenCV library
end_time = time.time()  # time library

# 최종 연산 수행 시간 계산
elapsed_time_by_cv2 = round(tick_meter.getTimeSec(), 3)
elapsed_time_by_time = round((end_time - start_time), 3)

# 이미지 출력
# cv2.imshow("", image)
# cv2.waitKey()
# cv2.destroyAllWindows()
# cv2.waitKey(1)

# 시간 측정 결과 출력
print(f"Elapsed time by cv2.TickMeter() : {elapsed_time_by_cv2}s.")
print(f"Elapsed time by time.time() : {elapsed_time_by_time}s.")
# Out:
# 총 반복 횟수 : 15,872,256번
# Elapsed time by cv2.TickMeter() : 21.854s.
# Elapsed time by time.time() : 21.854s.

# %% [markdown]
# ## <font color="#CC3D3D">Training #1: Video transition effects</font>
# <hr>
#
# - 개요
#     - 두 동영상 클립 사이에 추가되는 애니메이션 효과
#     - 페이드 인(fade-in), 페이드 아웃(fade-out), 디졸브(dissolve), 밀기, 확대 등
# <hr>
#
# - 구현할 기능
#     - 두 개의 동영상을 동시에 열기
#     - 첫 번째 동영상의 마지막 n개 프레임과 두 번째 동영상의 처음 n개 프레임을 합성
#     - 합성된 영상을 동영상으로 저장하기

# %%
# Training: Video transition effects - 실습: 비디오 전환 효과
import sys
import cv2
import numpy as np

# 두 개의 동영상 가져오기
capture1 = cv2.VideoCapture("./videos/video1.mp4")
capture2 = cv2.VideoCapture("./videos/video2.mp4")

# 예외 처리
if not capture1.isOpened() or not capture2.isOpened():
    print("Video open failed!")
    sys.exit()

# 두 동영상의 크기와 fps는 같다고 가정
frame_count1 = round(capture1.get(cv2.CAP_PROP_FRAME_COUNT))
frame_count2 = round(capture2.get(cv2.CAP_PROP_FRAME_COUNT))
fps = capture1.get(cv2.CAP_PROP_FPS)
effect_frames = int(fps * 2)  # 초당 프레임의 두 배 = 2초(48 프레임)

print("video1.mp4 frame count :", frame_count1)
print("video2.mp4 frame count :", frame_count2)
print("FPS :", fps)

delay = int(1000 / fps)

width = round(capture1.get(cv2.CAP_PROP_FRAME_WIDTH))
height = round(capture1.get(cv2.CAP_PROP_FRAME_HEIGHT))

fourcc = cv2.VideoWriter_fourcc(*"MJPG")

# 출력 동영상 객체 생성
out = cv2.VideoWriter("./videos/transition.avi", fourcc, fps, (width, height))

# 1번 동영상 복사
for i in range(frame_count1 - effect_frames):
    retval1, frame1 = capture1.read()
    
    # 예외 처리
    if not retval1:
        print('frame read error!')
        break
    
    out.write(frame1)
    
    cv2.imshow("output", frame1)
    cv2.waitKey(delay)
    

# 첫 번째 동영상의 뒷 부분 2초, 두 번째 동영상의 첫 부분 2초를 합성
for i in range(effect_frames):
    retval1, frame1 = capture1.read()
    retval2, frame2 = capture2.read()
    
    # 예외 처리
    if not retval1 or not retval2:
        print('frame read error!')
        break
    
    # 밀어내기
    # dx = int(width * i / effect_frames)  # 0부터 ~ 1280까지 약 26씩 증가
    # frame = np.zeros((height, width, 3), np.uint8)
    # frame[:, :dx] = frame2[:, :dx]
    # frame[:, dx:width] = frame1[:, dx:width]
    
    # 디졸브
    alpha_ = 1.0 - i / effect_frames
    frame = cv2.addWeighted(src1=frame1, alpha=alpha_, src2=frame2, beta=1 - alpha_, gamma=0)  # alpha + (1 - alpha) = 1
    
    out.write(frame)
    
    cv2.imshow("output", frame)
    cv2.waitKey(delay)
    
# 2번 동영상 복사
for i in range(effect_frames, frame_count2):
    retval2, frame2 = capture2.read()
    
    # 예외 처리
    if not retval2:
        print('frame read error!')
        break
    
    out.write(frame2)
    
    cv2.imshow("output", frame2)
    cv2.waitKey(delay)

# 후처리
print("\ntransition.avi file is successfully generated!")
capture1.release()
capture2.release()
out.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# video1.mp4 frame count : 85
# video2.mp4 frame count : 121
# FPS : 24.0
#
# output.avi file is successfully generated!
# -1
